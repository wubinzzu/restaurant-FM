# %%
import operator

from pprint import pprint

# %%
c_dict = dict()

f = open('../python/data/category/500.txt')

for line in f:
    line = line.strip()
    (category, cnt) = line.split('\t',1)
    
    c_dict[category] = int(cnt)
    print category
# Out:
# bars
# american (new)
# breakfast & brunch
# seafood
# italian
# japanese
# american (traditional)
# mexican
# pizza
# french
# coffee & tea
# sushi bars
# chinese
# asian fusion
# bakeries
# desserts
# sandwiches
# ice cream & frozen yogurt
# indian
# thai
# burgers
# vietnamese
# cafes
# tapas/small plates
# vegetarian
# steakhouses
# tapas bars
# dance clubs
# vegan
# venues & event spaces
# mediterranean
# gluten-free
# diners
# spanish
# creperies
# breweries
# latin american
# pakistani
# peruvian
# korean
# southern
# tea rooms
# basque
# gastropubs
# specialty food
# cajun/creole
# soul food
# irish
# delis
# music venues
# food trucks
# burmese
# german
# middle eastern
# live/raw food
# fish & chips
# grocery
# salad
# brasseries
# gelato
# greek
# comfort food
# bubble tea
# malaysian
# cupcakes
# caribbean
# barbeque
# juice bars & smoothies
# british
# donuts
# performing arts
# moroccan
# singaporean
# piano bars
# caterers
# argentine
# indonesian
# food
# portuguese
# ...

# %%
sorted_c = sorted(c_dict.items(), key=lambda x:x[1], reverse=True)

# %%
for
# Out:
# [('bars', 74),
#  ('american (new)', 69),
#  ('breakfast & brunch', 59),
#  ('seafood', 42),
#  ('italian', 39),
#  ('japanese', 35),
#  ('american (traditional)', 31),
#  ('mexican', 26),
#  ('pizza', 25),
#  ('french', 23),
#  ('coffee & tea', 23),
#  ('sushi bars', 23),
#  ('chinese', 22),
#  ('asian fusion', 22),
#  ('bakeries', 22),
#  ('desserts', 20),
#  ('sandwiches', 20),
#  ('ice cream & frozen yogurt', 16),
#  ('indian', 15),
#  ('thai', 15),
#  ('burgers', 15),
#  ('vietnamese', 13),
#  ('cafes', 11),
#  ('tapas/small plates', 10),
#  ('vegetarian', 10),
#  ('steakhouses', 10),
#  ('tapas bars', 10),
#  ('dance clubs', 9),
#  ('vegan', 8),
#  ('venues & event spaces', 8),
#  ('spanish', 7),
#  ('mediterranean', 7),
#  ('gluten-free', 7),
#  ('diners', 7),
#  ('creperies', 7),
#  ('breweries', 7),
#  ('pakistani', 6),
#  ('latin american', 6),
#  ('peruvian', 6),
#  ('korean', 6),
#  ('southern', 6),
#  ('gastropubs', 5),
#  ('specialty food', 5),
#  ('cajun/creole', 5),
# ...
